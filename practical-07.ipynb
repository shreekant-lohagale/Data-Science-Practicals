# %% [markdown]
# ## Name : Shreekant Sunil Lohagale
# ## Year & Div : TY-AIML-B
# ## Roll No. : 32

# %% [markdown]
# ## Assignment No 7
#
# ---
# ### Build and evaluate a Linear Regression model.Use train-test split, plot predicted vs actual.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, confusion_matrix, r2_score, accuracy_score

# %%
df = pd.read_csv('Dataset/placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.sample(5)
# Out:
#      cgpa  package
# 49   8.87     4.62
# 52   8.37     4.11
# 159  8.71     4.08
# 57   6.60     1.94
# 71   7.47     3.34

# %%
df.shape
# Out:
# (200, 2)

# %%
df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (160, 1)

# %%
X_test.shape
# Out:
# (40, 1)

# %%
y_train.shape
# Out:
# (160,)

# %%
y_test.shape
# Out:
# (40,)

# %%
lr = LinearRegression().fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([2.78031348, 3.13635249, 3.1995207 , 2.38981908, 3.52684689,
#        3.76803461, 3.16506531, 2.54486832, 3.17655044, 3.4923915 ,
#        1.90744364, 2.34962112, 3.6876387 , 2.75734322, 3.47516381,
#        3.04447145, 2.32665086, 3.20526327, 2.17734418, 3.314372  ,
#        2.45298729, 2.90090734, 3.32011456, 2.87219451, 3.33734226,
#        2.19457187, 1.41932564, 2.7114027 , 3.18229301, 2.32665086,
#        3.74506435, 2.95833298, 3.68189614, 2.97556068, 2.59080884,
#        3.34882738, 2.47595755, 3.07318428, 4.17575671, 2.95833298])

# %%
X_test.iloc[10]
# Out:
# cgpa    5.11
# Name: 66, dtype: float64

# %%
y_test.iloc[10]
# Out:
# np.float64(1.63)

# %%
lr.predict(X_test.iloc[10].values.reshape(1, 1))
# Out:
# c:\Users\iiiaamnooob\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.90744364])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7730984312051673
